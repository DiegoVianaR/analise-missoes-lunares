# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoVianaR/analise-missoes-lunares/blob/Diego/Teste_Lunar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importar dados missoes lunares
# !git clone https://github.com/ChiaviniK/analise-missoes-lunares.git
# Out:
# fatal: destination path 'analise-missoes-lunares' already exists and is not an empty directory.

# %%
import pandas as pd
df_lua = pd.read_csv("/content/analise-missoes-lunares/Moonlanding.csv")
display(df_lua)
# Out:
#                    Mission       Spacecraft Launch Date      Carrier Rocket  \
# 0       Pioneer 0 (Able I)        Pioneer 0   17-Aug-58   Thor DM-18 Able I
# 1            Luna E-1 No.1    Luna E-1 No.1   23-Sep-58                Luna
# 2      Pioneer 1 (Able II)        Pioneer 1   11-Oct-58   Thor DM-18 Able I
# 3            Luna E-1 No.2    Luna E-1 No.2   11-Oct-58                Luna
# 4     Pioneer 2 (Able III)        Pioneer 2   08-Nov-58   Thor DM-18 Able I
# ..                     ...              ...         ...                 ...
# 161  Peregrine Mission One        Peregrine   08-Jan-24  Vulcan Centaur VC2
# 162  Peregrine Mission One      Colmena ? 5   08-Jan-24  Vulcan Centaur VC2
# 163  Peregrine Mission One             Iris   08-Jan-24  Vulcan Centaur VC2
# 164                   IM-1  Nova-C Odysseus   14-Feb-24         Falcon 9 B5
# 165                   IM-1         EagleCam   14-Feb-24         Falcon 9 B5
#
# ...

# %%
# Média de foguete utilizados
frequencia = df_lua["Carrier Rocket"].value_counts()

display(frequencia)
# Out:
# Carrier Rocket
# Proton-K/D                  24
# Molniya-M                   12
# SLS Block 1                 11
# Saturn V                    10
# Luna                         9
# Atlas LV-3 Agena-B           6
# Atlas SLV-3 Agena-D          5
# Molniya-L                    5
# Long March 3C                4
# Atlas LV-3C Centaur-D        4
# Falcon 9 Block 5             4
# Long March 3B                4
# Long March 5                 4
# Thor DM-18 Able I            3
#   H-IIA                      3
# Vulcan Centaur VC2           3
# H-IIA 2022                   3
# Atlas-D Able                 3
# Atlas SLV-3C Centaur-D       3
# Molniya                      3
# Long March 4C                3
# Juno II                      2
# Delta E1                     2
# Falcon 9                     2
# Delta II 7925                2
# PSLV-XL C11                  2
# Atlas V 401                  2
# Falcon 9 B5                  2
# Delta 1913                   1
# ...

# %%
# Média de foguetes utilizados
frequencia = (
    df_lua["Carrier Rocket"]
    .value_counts()
    .reset_index()
)

frequencia.columns = ["Modelo do Foguete", "Quantidade de Utilizações"]

display(frequencia)
# Out:
#            Modelo do Foguete  Quantidade de Utilizações
# 0                 Proton-K/D                         24
# 1                  Molniya-M                         12
# 2                SLS Block 1                         11
# 3                   Saturn V                         10
# 4                       Luna                          9
# 5         Atlas LV-3 Agena-B                          6
# 6        Atlas SLV-3 Agena-D                          5
# 7                  Molniya-L                          5
# 8              Long March 3C                          4
# 9      Atlas LV-3C Centaur-D                          4
# 10          Falcon 9 Block 5                          4
# 11             Long March 3B                          4
# 12              Long March 5                          4
# 13         Thor DM-18 Able I                          3
# 14                     H-IIA                          3
# 15        Vulcan Centaur VC2                          3
# ...
